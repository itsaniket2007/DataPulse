# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sales_data.csv")

df
# Out:
#     Order_ID  Order_Date Customer_ID     Product     Category Region  \
# 0       1001  2026-01-03        C001      Laptop  Electronics  North
# 1       1002  2026-01-04        C002       Mouse  Accessories  South
# 2       1003  2026-01-05        C003    Keyboard  Accessories   West
# 3       1004  2026-01-06        C004     Monitor  Electronics   East
# 4       1005  2026-01-08        C005  Headphones  Accessories  North
# 5       1006  2026-01-10        C006      Laptop  Electronics  South
# 6       1007  2026-01-11        C007       Mouse  Accessories   West
# 7       1008  2026-01-13        C008     Monitor  Electronics   East
# 8       1009  2026-01-15        C009    Keyboard  Accessories  North
# 9       1010  2026-01-16        C010  Headphones  Accessories  South
# 10      1011  2026-01-18        C011      Laptop  Electronics   West
# 11      1012  2026-01-20        C012     Monitor  Electronics  North
# 12      1013  2026-01-22        C013       Mouse  Accessories   East
# ...

# %%
# First Look 
df.head()
# Out:
#    Order_ID  Order_Date Customer_ID     Product     Category Region  Quantity  \
# 0      1001  2026-01-03        C001      Laptop  Electronics  North         1
# 1      1002  2026-01-04        C002       Mouse  Accessories  South         2
# 2      1003  2026-01-05        C003    Keyboard  Accessories   West         1
# 3      1004  2026-01-06        C004     Monitor  Electronics   East         1
# 4      1005  2026-01-08        C005  Headphones  Accessories  North         2
#
#    Unit_Price  Discount Payment_Method Returned
# 0       65000      0.05            UPI       No
# 1         800      0.00    Credit Card       No
# 2        1800      0.10            UPI       No
# 3       15000      0.05     Debit Card       No
# 4        2500      0.00            UPI      Yes

# %%
# Base Look
df.tail()
# Out:
#     Order_ID  Order_Date Customer_ID     Product     Category Region  \
# 10      1011  2026-01-18        C011      Laptop  Electronics   West
# 11      1012  2026-01-20        C012     Monitor  Electronics  North
# 12      1013  2026-01-22        C013       Mouse  Accessories   East
# 13      1014  2026-01-24        C014    Keyboard  Accessories  South
# 14      1015  2026-01-25        C015  Headphones  Accessories   West
#
#     Quantity  Unit_Price  Discount Payment_Method Returned
# 10         1       68000      0.05    Credit Card       No
# 11         1       15500      0.00            UPI       No
# 12         4         700      0.05           Cash       No
# 13         1        2100      0.00     Debit Card       No
# 14         2        2600      0.10            UPI       No

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 15
# Number of columns: 11

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Product', 'Category',
#        'Region', 'Quantity', 'Unit_Price', 'Discount', 'Payment_Method',
#        'Returned'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        15 non-null     int64
#  1   Order_Date      15 non-null     object
#  2   Customer_ID     15 non-null     object
#  3   Product         15 non-null     object
#  4   Category        15 non-null     object
#  5   Region          15 non-null     object
#  6   Quantity        15 non-null     int64
#  7   Unit_Price      15 non-null     int64
#  8   Discount        15 non-null     float64
#  9   Payment_Method  15 non-null     object
#  10  Returned        15 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#           Order_ID   Quantity    Unit_Price   Discount
# count    15.000000  15.000000     15.000000  15.000000
# mean   1008.000000   1.666667  17696.666667   0.042000
# std       4.472136   0.899735  26766.813586   0.040036
# min    1001.000000   1.000000    700.000000   0.000000
# 25%    1004.500000   1.000000   1850.000000   0.000000
# 50%    1008.000000   1.000000   2600.000000   0.050000
# 75%    1011.500000   2.000000  15250.000000   0.065000
# max    1015.000000   4.000000  72000.000000   0.100000

# %%
# Check missing values
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Product           0
# Category          0
# Region            0
# Quantity          0
# Unit_Price        0
# Discount          0
# Payment_Method    0
# Returned          0
# dtype: int64

# %%
# total missing values 
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# check Duplicates 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# categorical columns
print("Categories:")
print(df["Category"].unique())

print("\nRegions:")
print(df["Region"].unique())

print("\nPayment Methods:")
print(df["Payment_Method"].unique())
# Out:
# Categories:
# ['Electronics' 'Accessories']
#
# Regions:
# ['North' 'South' 'West' 'East']
#
# Payment Methods:
# ['UPI' 'Credit Card' 'Debit Card' 'Cash']

# %%
df["Category"].value_counts()
# Out:
# Category
# Accessories    9
# Electronics    6
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# North    4
# South    4
# West     4
# East     3
# Name: count, dtype: int64

# %%
# business calculation
df["Sales"] = df["Quantity"] * df["Unit_Price"]

# %%
df[["Order_ID", "Product", "Quantity", "Unit_Price", "Sales"]]
# Out:
#     Order_ID     Product  Quantity  Unit_Price  Sales
# 0       1001      Laptop         1       65000  65000
# 1       1002       Mouse         2         800   1600
# 2       1003    Keyboard         1        1800   1800
# 3       1004     Monitor         1       15000  15000
# 4       1005  Headphones         2        2500   5000
# 5       1006      Laptop         1       72000  72000
# 6       1007       Mouse         3         750   2250
# 7       1008     Monitor         2       14000  28000
# 8       1009    Keyboard         2        1900   3800
# 9       1010  Headphones         1        2800   2800
# 10      1011      Laptop         1       68000  68000
# 11      1012     Monitor         1       15500  15500
# 12      1013       Mouse         4         700   2800
# 13      1014    Keyboard         1        2100   2100
# 14      1015  Headphones         2        2600   5200

# %%
total_sales = df["Sales"].sum()

print("Total Sales: ₹", total_sales)
# Out:
# Total Sales: ₹ 290850

# %%
# Which product generated the most sales?
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

product_sales
# Out:
# Product
# Laptop        205000
# Monitor        58500
# Headphones     13000
# Keyboard        7700
# Mouse           6650
# Name: Sales, dtype: int64

# %%
""" Day 1 Observations

- The dataset contains 15 orders.
- There are 15 customers in the current dataset.
- The dataset contains Electronics and Accessories categories.
- There are no missing values.
- There are no duplicate records.
- Sales were calculated using Quantity × Unit Price.
- The product with the highest total sales was ______. ## """
# Out:
# ' Day 1 Observations\n\n- The dataset contains 15 orders.\n- There are 15 customers in the current dataset.\n- The dataset contains Electronics and Accessories categories.\n- There are no missing values.\n- There are no duplicate records.\n- Sales were calculated using Quantity × Unit Price.\n- The product with the highest total sales was ______. ## '
